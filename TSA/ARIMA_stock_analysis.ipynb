# %%
####################################################### IMPORTS ###################################################################
from arch import arch_model
import pandas_datareader.data as web
import random
import datetime
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm

import warnings
warnings.filterwarnings("ignore")

# %%
####################################################### DATA EXTRACTION ###################################################################
# datetime date uses the yyyy, mm, dd format
before = int(time.mktime(datetime.date(2018,1,1).timetuple()))# Starting date
today  = int(time.mktime(datetime.datetime.today().timetuple()))# Last date
ticker = 'aapl'
url=f"https://query1.finance.yahoo.com/v7/finance/download/{ticker}?period1={before}&period2={today}&interval=1d&events=history&includeAdjustedClose=true"
df = pd.read_csv(url)
df['date'] = [datetime.datetime.strptime(date, '%Y-%m-%d') for date in df["Date"]]
#df['returns'] = 100 * df['Adj Close'].pct_change()
df['returns'] = 100*(np.log(df["Adj Close"].shift(1)) - np.log(df["Adj Close"]))
df.dropna(inplace=True)
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 1     2018-01-03   43.132500   43.637501   42.990002   43.057499   40.943363
# 2     2018-01-04   43.134998   43.367500   43.020000   43.257500   41.133545
# 3     2018-01-05   43.360001   43.842499   43.262501   43.750000   41.601864
# 4     2018-01-08   43.587502   43.902500   43.482498   43.587502   41.447346
# 5     2018-01-09   43.637501   43.764999   43.352501   43.582500   41.442581
# ...          ...         ...         ...         ...         ...         ...
# 1253  2022-12-22  134.350006  134.559998  130.300003  132.229996  132.229996
# 1254  2022-12-23  130.919998  132.419998  129.639999  131.860001  131.860001
# 1255  2022-12-27  131.380005  131.410004  128.720001  130.029999  130.029999
# 1256  2022-12-28  129.669998  131.029999  125.870003  126.040001  126.040001
# 1257  2022-12-29  127.989998  130.479996  127.815002  129.419998  129.419998
#
#          Volume       date   returns
# 1     118071600 2018-01-03  0.017430
# 2      89738400 2018-01-04 -0.463425
# 3      94640000 2018-01-05 -1.132101
# 4      82271200 2018-01-08  0.372112
# 5      86336000 2018-01-09  0.011497
# ...         ...        ...       ...
# 1253   77852100 2022-12-22  2.405975
# 1254   63771000 2022-12-23  0.280204
# 1255   69007800 2022-12-27  1.397558
# 1256   85323900 2022-12-28  3.116586
# 1257   50314404 2022-12-29 -2.646359
#
# [1257 rows x 9 columns]

# %%
################################################# ACF and PACF to find out the best ARMA model ###################################################################
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(321)
fig = sm.graphics.tsa.plot_acf(df['returns'], lags=30, ax=ax1)
ax2 = fig.add_subplot(322)
fig = sm.graphics.tsa.plot_pacf(df['returns'], lags=30, ax=ax2)

# %%
####################################################### ARMA MODELS FITTING ###################################################################

my_arma = (0, 0, 0, 0)
result = []
for i in range(5):
    for j in range(5):
        try:
            arma_model = sm.tsa.arima.ARIMA(df['returns'], order=(i, 0, j)).fit()
            result.append([i, j, arma_model.aic, arma_model.bic])
        except Exception as exception:
            pass
result = pd.DataFrame(result,columns=['p','q',"AIC","BIC"])
print(result)

print("\n######################################################################################################")
print("Using loops or directly the auto_arima function, we see that this time series can be modeled with ARIMA")
print("Best model => ARIMA(2,2)")
print("______________________________________________________________________________________________________")
# Out:
#     p  q          AIC          BIC
# 0   0  0  5448.970074  5459.243040
# 1   0  1  5435.358206  5450.767655
# 2   0  2  5437.328058  5457.873991
# 3   0  3  5438.923976  5464.606392
# 4   0  4  5440.751965  5471.570864
# 5   1  0  5435.338942  5450.748392
# 6   1  1  5437.315479  5457.861411
# 7   1  2  5432.323715  5458.006131
# 8   1  3  5440.898460  5471.717360
# 9   1  4  5441.040377  5476.995760
# 10  2  0  5437.322222  5457.868155
# 11  2  1  5439.256656  5464.939072
# 12  2  2  5407.463017  5438.281917
# 13  2  3  5442.609111  5478.564493
# 14  2  4  5440.201468  5481.293334
# 15  3  0  5438.930265  5464.612681
# 16  3  1  5440.921933  5471.740832
# 17  3  2  5439.994391  5475.949773
# 18  3  3  5442.239620  5483.331486
# 19  3  4  5410.960457  5457.188806
# 20  4  0  5440.876105  5471.695005
# 21  4  1  5427.091296  5463.046678
# 22  4  2  5440.119332  5481.211198
# 23  4  3  5435.650016  5481.878365
# 24  4  4  5446.354931  5497.719763
#
# ######################################################################################################
# Using loops or directly the auto_arima function, we see that this time series can be modeled with ARIMA
# Best model => ARIMA(2,2)
# ______________________________________________________________________________________________________

# %%
arma_model = sm.tsa.arima.ARIMA(df['returns'], order=(2, 0, 2)).fit()
arma_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                returns   No. Observations:                 1257
# Model:                 ARIMA(2, 0, 2)   Log Likelihood               -2697.732
# Date:                Thu, 29 Dec 2022   AIC                           5407.463
# Time:                        19:32:59   BIC                           5438.282
# Sample:                             0   HQIC                          5419.046
#                                - 1257
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0913      0.057     -1.602      0.109      -0.203       0.020
# ar.L1         -1.7758      0.030    -58.578      0.000      -1.835      -1.716
# ar.L2         -0.9128      0.030    -30.635      0.000      -0.971      -0.854
# ma.L1          1.7154      0.039     43.888      0.000       1.639       1.792
# ma.L2          0.8364      0.038     22.091      0.000       0.762       0.911
# sigma2         4.2812      0.112     38.333      0.000       4.062       4.500
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.62   Jarque-Bera (JB):               660.72
# Prob(Q):                              0.43   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.14   Skew:                             0.29
# Prob(H) (two-sided):                  0.19   Kurtosis:                         6.50
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
#################################################### TESTING FOR RESIDUALS NORMALITY ###################################################################
jb = sm.stats.stattools.jarque_bera(df["returns"])
print("Jarque Bera   :" ,jb)
print("Looking at the p-value of the test and the statistic, we reject the null hypothesis of normality.")
print("Coherent since we're dealing with financial data.")
print("_________________________________________________________________________________________________")

################################################### TESTING FOR RESIDUALS HETEROSKEDASTICITY ###################################################################
am = arch_model(df["returns"]*100)
print(am.fit().summary())
print("\nThis test indicates that we need a GARCH model to fit the time series.")
print("______________________________________________________________________")
# Out:
# Jarque Bera   : (1123.9040248693987, 8.858127054224235e-245, 0.23189222748892524, 7.609087983934901)
# Looking at the p-value of the test and the statistic, we reject the null hypothesis of normality.
# Coherent since we're dealing with financial data.
# _________________________________________________________________________________________________
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 9415.75887790847
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 8380.621178615133
# Iteration:      3,   Func. Count:     18,   Neg. LLF: 2550796.7386048627
# Iteration:      4,   Func. Count:     26,   Neg. LLF: 8378.054705057548
# Iteration:      5,   Func. Count:     31,   Neg. LLF: 8377.995596321496
# Iteration:      6,   Func. Count:     36,   Neg. LLF: 8377.994212343809
# Iteration:      7,   Func. Count:     41,   Neg. LLF: 8377.994105596175
# Iteration:      8,   Func. Count:     46,   Neg. LLF: 8377.99397914779
# Iteration:      9,   Func. Count:     51,   Neg. LLF: 8377.993354849646
# Iteration:     10,   Func. Count:     56,   Neg. LLF: 8377.991686904395
# Iteration:     11,   Func. Count:     61,   Neg. LLF: 8377.988145927431
# Iteration:     12,   Func. Count:     66,   Neg. LLF: 8377.978345086638
# Iteration:     13,   Func. Count:     71,   Neg. LLF: 8377.945783538258
# Iteration:     14,   Func. Count:     76,   Neg. LLF: 8377.872544852864
# Iteration:     15,   Func. Count:     81,   Neg. LLF: 8377.713762229407
# Iteration:     16,   Func. Count:     86,   Neg. LLF: 8377.395009607828
# Iteration:     17,   Func. Count:     91,   Neg. LLF: 8376.777630876673
# Iteration:     18,   Func. Count:     96,   Neg. LLF: 8376.094948950147
# Iteration:     19,   Func. Count:    101,   Neg. LLF: 8375.47123581843
# Iteration:     20,   Func. Count:    106,   Neg. LLF: 8375.314866172292
# Iteration:     21,   Func. Count:    111,   Neg. LLF: 8375.2831759018
# Iteration:     22,   Func. Count:    116,   Neg. LLF: 8375.275003864008
# Iteration:     23,   Func. Count:    121,   Neg. LLF: 8375.275411447445
# Iteration:     24,   Func. Count:    128,   Neg. LLF: 8375.274654113833
# Iteration:     25,   Func. Count:    133,   Neg. LLF: 8375.274651478725
# Iteration:     26,   Func. Count:    137,   Neg. LLF: 8375.274651478267
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8375.274651478725
#             Iterations: 26
#             Function evaluations: 137
#             Gradient evaluations: 26
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                returns   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:               -8375.27
# Distribution:                  Normal   AIC:                           16758.5
# Method:            Maximum Likelihood   BIC:                           16779.1
#                                         No. Observations:                 1257
# Date:                Thu, Dec 29 2022   Df Residuals:                     1256
# Time:                        19:39:41   Df Model:                            1
#                                Mean Model
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# mu           -20.5912      5.181     -3.975  7.047e-05 [-30.745,-10.437]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega       1734.4690    562.434      3.084  2.043e-03 [6.321e+02,2.837e+03]
# alpha[1]       0.1348  2.831e-02      4.763  1.908e-06   [7.936e-02,  0.190]
# beta[1]        0.8308  2.928e-02     28.371 4.549e-177     [  0.773,  0.888]
# ============================================================================
#
# Covariance estimator: robust
#
# This test indicates that we need a GARCH model to fit the time series.
# ______________________________________________________________________

# %%
################################################### GARCH MODEL FITTING ####################################################################
import statsmodels.api as sm
result = []
for i in range(4):
    for j in range(4):
        try:
            garch_model = arch_model(df['returns'], vol='Garch', p=i, o=0, q=j, dist='skewt').fit()
            result.append([i, j, garch_model.aic, garch_model.bic])
        except Exception as exception:
            pass

result = pd.DataFrame(result,columns=['p','q',"AIC","BIC"])
#results in the next cell
# Out:
# Iteration:      1,   Func. Count:      7,   Neg. LLF: 6973.651543402846
# Iteration:      2,   Func. Count:     16,   Neg. LLF: 9213.592867373514
# Iteration:      3,   Func. Count:     25,   Neg. LLF: 16777.095560838206
# Iteration:      4,   Func. Count:     33,   Neg. LLF: 3941.4977626834643
# Iteration:      5,   Func. Count:     40,   Neg. LLF: 3694.8994931209877
# Iteration:      6,   Func. Count:     47,   Neg. LLF: 2614.062137350247
# Iteration:      7,   Func. Count:     54,   Neg. LLF: 2606.7622919467995
# Iteration:      8,   Func. Count:     61,   Neg. LLF: 2607.6750226018285
# Iteration:      9,   Func. Count:     68,   Neg. LLF: 2605.844780788575
# Iteration:     10,   Func. Count:     74,   Neg. LLF: 2605.776760764956
# Iteration:     11,   Func. Count:     80,   Neg. LLF: 2605.7728836512315
# Iteration:     12,   Func. Count:     86,   Neg. LLF: 2605.7728312546096
# Iteration:     13,   Func. Count:     91,   Neg. LLF: 2605.772831254614
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2605.7728312546096
#             Iterations: 13
#             Function evaluations: 91
#             Gradient evaluations: 13
# Iteration:      1,   Func. Count:      8,   Neg. LLF: 7137.504544679114
# Iteration:      2,   Func. Count:     19,   Neg. LLF: 53180.19574795624
# Iteration:      3,   Func. Count:     29,   Neg. LLF: 77525.07060935994
# Iteration:      4,   Func. Count:     38,   Neg. LLF: 2919.165530836879
# Iteration:      5,   Func. Count:     47,   Neg. LLF: 2622.1156900493074
# Iteration:      6,   Func. Count:     56,   Neg. LLF: 3778.705911442853
# Iteration:      7,   Func. Count:     64,   Neg. LLF: 2554.0355907554217
# Iteration:      8,   Func. Count:     72,   Neg. LLF: 2553.6891838958063
# Iteration:      9,   Func. Count:     80,   Neg. LLF: 2553.636220012596
# Iteration:     10,   Func. Count:     87,   Neg. LLF: 2553.6339583065183
# Iteration:     11,   Func. Count:     94,   Neg. LLF: 2553.63394808779
# Iteration:     12,   Func. Count:    100,   Neg. LLF: 2553.6339480878223
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2553.63394808779
#             Iterations: 12
#             Function evaluations: 100
#             Gradient evaluations: 12
# Iteration:      1,   Func. Count:      9,   Neg. LLF: 71162.00741626779
# Iteration:      2,   Func. Count:     20,   Neg. LLF: 61554.613555392934
# Iteration:      3,   Func. Count:     30,   Neg. LLF: 34899.47037318211
# Iteration:      4,   Func. Count:     41,   Neg. LLF: 12884.631066114373
# Iteration:      5,   Func. Count:     50,   Neg. LLF: 3758.06220340256
# Iteration:      6,   Func. Count:     59,   Neg. LLF: 2570.8374857016765
# Iteration:      7,   Func. Count:     68,   Neg. LLF: 2562.2754753934905
# Iteration:      8,   Func. Count:     77,   Neg. LLF: 3665.5419481828267
# Iteration:      9,   Func. Count:     86,   Neg. LLF: 2556.501759877837
# Iteration:     10,   Func. Count:     95,   Neg. LLF: 2554.4310472528477
# Iteration:     11,   Func. Count:    104,   Neg. LLF: 2553.685661740096
# Iteration:     12,   Func. Count:    112,   Neg. LLF: 2553.6469488243047
# Iteration:     13,   Func. Count:    120,   Neg. LLF: 2553.6363554499585
# Iteration:     14,   Func. Count:    128,   Neg. LLF: 2553.634167374842
# Iteration:     15,   Func. Count:    136,   Neg. LLF: 2553.6339571995563
# Iteration:     16,   Func. Count:    144,   Neg. LLF: 2553.633948883168
# Iteration:     17,   Func. Count:    152,   Neg. LLF: 2553.633947930298
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2553.633947930298
#             Iterations: 17
#             Function evaluations: 152
#             Gradient evaluations: 17
# Iteration:      1,   Func. Count:     10,   Neg. LLF: 68278.36583793916
# Iteration:      2,   Func. Count:     22,   Neg. LLF: 117791.02690260985
# Iteration:      3,   Func. Count:     33,   Neg. LLF: 4343.4560036168
# Iteration:      4,   Func. Count:     44,   Neg. LLF: 3893.3681470661213
# Iteration:      5,   Func. Count:     54,   Neg. LLF: 2575.700781180422
# Iteration:      6,   Func. Count:     64,   Neg. LLF: 2589.1535307794165
# Iteration:      7,   Func. Count:     74,   Neg. LLF: 2569.3424895775256
# Iteration:      8,   Func. Count:     84,   Neg. LLF: 2697.132794744354
# Iteration:      9,   Func. Count:     94,   Neg. LLF: 2555.140110140549
# Iteration:     10,   Func. Count:    104,   Neg. LLF: 2556.7378660188756
# Iteration:     11,   Func. Count:    114,   Neg. LLF: 2555.388425041258
# Iteration:     12,   Func. Count:    124,   Neg. LLF: 2553.625579718758
# Iteration:     13,   Func. Count:    133,   Neg. LLF: 2553.598487205579
# Iteration:     14,   Func. Count:    142,   Neg. LLF: 2553.5969488068563
# Iteration:     15,   Func. Count:    151,   Neg. LLF: 2553.59686581518
# Iteration:     16,   Func. Count:    160,   Neg. LLF: 2553.596862556826
# Iteration:     17,   Func. Count:    168,   Neg. LLF: 2553.5968625568366
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2553.596862556826
#             Iterations: 17
#             Function evaluations: 168
#             Gradient evaluations: 17
# Iteration:      1,   Func. Count:      8,   Neg. LLF: 6891.9026767214
# Iteration:      2,   Func. Count:     18,   Neg. LLF: 8618.594007757678
# Iteration:      3,   Func. Count:     28,   Neg. LLF: 20952.197685172887
# Iteration:      4,   Func. Count:     36,   Neg. LLF: 4423.1927870536565
# Iteration:      5,   Func. Count:     44,   Neg. LLF: 5795.380412629184
# Iteration:      6,   Func. Count:     52,   Neg. LLF: 3724.576194291979
# Iteration:      7,   Func. Count:     60,   Neg. LLF: 2593.4819284836753
# Iteration:      8,   Func. Count:     68,   Neg. LLF: 2589.739192532484
# Iteration:      9,   Func. Count:     76,   Neg. LLF: 2588.0304639177016
# Iteration:     10,   Func. Count:     83,   Neg. LLF: 2588.0301299641287
# Iteration:     11,   Func. Count:     90,   Neg. LLF: 2588.0301187233645
# Iteration:     12,   Func. Count:     97,   Neg. LLF: 2588.0301176923977
# Iteration:     13,   Func. Count:    103,   Neg. LLF: 2588.030117692394
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2588.0301176923977
#             Iterations: 13
#             Function evaluations: 103
#             Gradient evaluations: 13
# Iteration:      1,   Func. Count:      9,   Neg. LLF: 7086.025736220861
# Iteration:      2,   Func. Count:     21,   Neg. LLF: 51985.58371387922
# Iteration:      3,   Func. Count:     32,   Neg. LLF: 46917.06329038658
# Iteration:      4,   Func. Count:     42,   Neg. LLF: 3047.0485161035067
# Iteration:      5,   Func. Count:     52,   Neg. LLF: 2603.199571148148
# Iteration:      6,   Func. Count:     61,   Neg. LLF: 3779.8192112816114
# Iteration:      7,   Func. Count:     70,   Neg. LLF: 2554.4410394928877
# Iteration:      8,   Func. Count:     79,   Neg. LLF: 2553.7230279977207
# Iteration:      9,   Func. Count:     87,   Neg. LLF: 2570.381162148522
# Iteration:     10,   Func. Count:     97,   Neg. LLF: 2554.907451990157
# Iteration:     11,   Func. Count:    106,   Neg. LLF: 2553.6172925847623
# Iteration:     12,   Func. Count:    114,   Neg. LLF: 2553.6153928196836
# Iteration:     13,   Func. Count:    122,   Neg. LLF: 2553.6151475232627
# Iteration:     14,   Func. Count:    130,   Neg. LLF: 2553.6151344719738
# Iteration:     15,   Func. Count:    137,   Neg. LLF: 2553.6151344719183
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2553.6151344719738
#             Iterations: 15
#             Function evaluations: 137
#             Gradient evaluations: 15
# Iteration:      1,   Func. Count:     10,   Neg. LLF: 71852.60397967345
# Iteration:      2,   Func. Count:     22,   Neg. LLF: 124830.35959104847
# Iteration:      3,   Func. Count:     33,   Neg. LLF: 17471.648443121976
# Iteration:      4,   Func. Count:     44,   Neg. LLF: 2652.0092649389308
# Iteration:      5,   Func. Count:     54,   Neg. LLF: 4441.989708289984
# Iteration:      6,   Func. Count:     65,   Neg. LLF: 2601.7796380460395
# Iteration:      7,   Func. Count:     75,   Neg. LLF: 2876.506917749143
# Iteration:      8,   Func. Count:     85,   Neg. LLF: 2560.879709223189
# Iteration:      9,   Func. Count:     95,   Neg. LLF: 2566.3758361193304
# Iteration:     10,   Func. Count:    105,   Neg. LLF: 2553.2376056916437
# Iteration:     11,   Func. Count:    114,   Neg. LLF: 2553.577480188491
# Iteration:     12,   Func. Count:    125,   Neg. LLF: 2553.6397569586115
# Iteration:     13,   Func. Count:    135,   Neg. LLF: 2553.152162720976
# Iteration:     14,   Func. Count:    144,   Neg. LLF: 2553.15197610995
# Iteration:     15,   Func. Count:    153,   Neg. LLF: 2553.1519674194324
# Iteration:     16,   Func. Count:    162,   Neg. LLF: 2553.151966552905
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2553.151966552905
#             Iterations: 16
#             Function evaluations: 162
#             Gradient evaluations: 16
# Iteration:      1,   Func. Count:     11,   Neg. LLF: 70195.31644501988
# Iteration:      2,   Func. Count:     24,   Neg. LLF: 123207.25936550704
# Iteration:      3,   Func. Count:     36,   Neg. LLF: 20980.189480053763
# Iteration:      4,   Func. Count:     48,   Neg. LLF: 3262.8802498183413
# Iteration:      5,   Func. Count:     60,   Neg. LLF: 4004.531462966342
# Iteration:      6,   Func. Count:     71,   Neg. LLF: 2621.525490222857
# Iteration:      7,   Func. Count:     82,   Neg. LLF: 2568.9151595768544
# Iteration:      8,   Func. Count:     93,   Neg. LLF: 3701.938969370732
# Iteration:      9,   Func. Count:    104,   Neg. LLF: 2558.882104063553
# Iteration:     10,   Func. Count:    115,   Neg. LLF: 2553.125690988973
# Iteration:     11,   Func. Count:    126,   Neg. LLF: 2551.8057847694085
# Iteration:     12,   Func. Count:    136,   Neg. LLF: 2551.8082339865414
# Iteration:     13,   Func. Count:    147,   Neg. LLF: 2551.7955716698934
# Iteration:     14,   Func. Count:    157,   Neg. LLF: 2551.7942287880933
# Iteration:     15,   Func. Count:    167,   Neg. LLF: 2551.7932419765975
# Iteration:     16,   Func. Count:    177,   Neg. LLF: 2551.79321254955
# Iteration:     17,   Func. Count:    187,   Neg. LLF: 2551.79321044716
# Iteration:     18,   Func. Count:    196,   Neg. LLF: 2551.7932104471306
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2551.79321044716
#             Iterations: 18
#             Function evaluations: 196
#             Gradient evaluations: 18
# Iteration:      1,   Func. Count:      9,   Neg. LLF: 6776.956821649162
# Iteration:      2,   Func. Count:     20,   Neg. LLF: 8313.752622475486
# Iteration:      3,   Func. Count:     31,   Neg. LLF: 28997.563531280102
# Iteration:      4,   Func. Count:     40,   Neg. LLF: 5494.333026081634
# Iteration:      5,   Func. Count:     49,   Neg. LLF: 10082.710413968434
# Iteration:      6,   Func. Count:     58,   Neg. LLF: 3980.5482628058326
# Iteration:      7,   Func. Count:     67,   Neg. LLF: 3019.6621238015555
# Iteration:      8,   Func. Count:     77,   Neg. LLF: 2607.8283384831957
# Iteration:      9,   Func. Count:     86,   Neg. LLF: 2583.9495429627764
# Iteration:     10,   Func. Count:     95,   Neg. LLF: 2582.3665080628957
# Iteration:     11,   Func. Count:    103,   Neg. LLF: 2582.21398069723
# Iteration:     12,   Func. Count:    111,   Neg. LLF: 2582.2007880698015
# Iteration:     13,   Func. Count:    119,   Neg. LLF: 2582.1976075524235
# Iteration:     14,   Func. Count:    127,   Neg. LLF: 2582.1975062497813
# Iteration:     15,   Func. Count:    135,   Neg. LLF: 2582.197502944044
# Iteration:     16,   Func. Count:    142,   Neg. LLF: 2582.1975029440005
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2582.197502944044
#             Iterations: 16
#             Function evaluations: 142
#             Gradient evaluations: 16
# Iteration:      1,   Func. Count:     10,   Neg. LLF: 7070.19889336609
# Iteration:      2,   Func. Count:     22,   Neg. LLF: 70498.11963770464
# Iteration:      3,   Func. Count:     33,   Neg. LLF: 2782.074717177677
# Iteration:      4,   Func. Count:     43,   Neg. LLF: 3853.7306812832335
# Iteration:      5,   Func. Count:     53,   Neg. LLF: 3520.693291024852
# Iteration:      6,   Func. Count:     63,   Neg. LLF: 4214.961575037781
# Iteration:      7,   Func. Count:     73,   Neg. LLF: 2570.0020326884023
# Iteration:      8,   Func. Count:     83,   Neg. LLF: 2557.628087220034
# Iteration:      9,   Func. Count:     93,   Neg. LLF: 2553.885726241012
# Iteration:     10,   Func. Count:    102,   Neg. LLF: 2555.866334376857
# Iteration:     11,   Func. Count:    112,   Neg. LLF: 5890.392005729492
# Iteration:     12,   Func. Count:    123,   Neg. LLF: 2553.6604599126804
# Iteration:     13,   Func. Count:    133,   Neg. LLF: 2553.6168694687094
# Iteration:     14,   Func. Count:    142,   Neg. LLF: 2553.6155960570677
# Iteration:     15,   Func. Count:    151,   Neg. LLF: 2553.6151789602973
# Iteration:     16,   Func. Count:    160,   Neg. LLF: 2553.6151360398344
# Iteration:     17,   Func. Count:    169,   Neg. LLF: 2553.6151344986424
# Iteration:     18,   Func. Count:    177,   Neg. LLF: 2553.6151344985237
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2553.6151344986424
#             Iterations: 18
#             Function evaluations: 177
#             Gradient evaluations: 18
# Iteration:      1,   Func. Count:     11,   Neg. LLF: 72220.18988754762
# Iteration:      2,   Func. Count:     24,   Neg. LLF: 39298.29510003684
# Iteration:      3,   Func. Count:     36,   Neg. LLF: 8971.068949837243
# Iteration:      4,   Func. Count:     48,   Neg. LLF: 2628.364561261854
# Iteration:      5,   Func. Count:     59,   Neg. LLF: 3713.9893424071433
# Iteration:      6,   Func. Count:     70,   Neg. LLF: 3609.3871049086492
# Iteration:      7,   Func. Count:     81,   Neg. LLF: 2685.155214350068
# Iteration:      8,   Func. Count:     92,   Neg. LLF: 2565.003405112856
# Iteration:      9,   Func. Count:    103,   Neg. LLF: 2553.446122222922
# Iteration:     10,   Func. Count:    113,   Neg. LLF: 2557.6790592943144
# Iteration:     11,   Func. Count:    124,   Neg. LLF: 2591.7643802057987
# Iteration:     12,   Func. Count:    136,   Neg. LLF: 2553.1787545861876
# Iteration:     13,   Func. Count:    146,   Neg. LLF: 2553.1527895465665
# Iteration:     14,   Func. Count:    156,   Neg. LLF: 2553.1519948042037
# Iteration:     15,   Func. Count:    166,   Neg. LLF: 2553.1519675645445
# Iteration:     16,   Func. Count:    176,   Neg. LLF: 2553.151966567008
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2553.151966567008
#             Iterations: 16
#             Function evaluations: 176
#             Gradient evaluations: 16
# Iteration:      1,   Func. Count:     12,   Neg. LLF: 70120.715863678
# Iteration:      2,   Func. Count:     26,   Neg. LLF: 124529.94513146814
# Iteration:      3,   Func. Count:     39,   Neg. LLF: 18708.69760022856
# Iteration:      4,   Func. Count:     52,   Neg. LLF: 3404.770308642634
# Iteration:      5,   Func. Count:     64,   Neg. LLF: 4056.3831645495998
# Iteration:      6,   Func. Count:     76,   Neg. LLF: 3177.6489599127735
# Iteration:      7,   Func. Count:     88,   Neg. LLF: 2605.055190060237
# Iteration:      8,   Func. Count:    100,   Neg. LLF: 2578.599190517245
# Iteration:      9,   Func. Count:    112,   Neg. LLF: 2557.143305783102
# Iteration:     10,   Func. Count:    124,   Neg. LLF: 2561.5844590832194
# Iteration:     11,   Func. Count:    136,   Neg. LLF: 2551.8449148630734
# Iteration:     12,   Func. Count:    147,   Neg. LLF: 2552.1536189594563
# Iteration:     13,   Func. Count:    159,   Neg. LLF: 2552.2076157974725
# Iteration:     14,   Func. Count:    171,   Neg. LLF: 2551.7805039852174
# Iteration:     15,   Func. Count:    182,   Neg. LLF: 2551.7792611748287
# Iteration:     16,   Func. Count:    193,   Neg. LLF: 2551.7791086612924
# Iteration:     17,   Func. Count:    204,   Neg. LLF: 2551.7790938879057
# Iteration:     18,   Func. Count:    214,   Neg. LLF: 2551.7790938878697
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2551.7790938879057
#             Iterations: 18
#             Function evaluations: 214
#             Gradient evaluations: 18

# %%
print(result)
print("\nThe analysis of the AIC and BIC components shows that this time serie can be modeled with GARCH.")
print("Best model => GARCH(1,0,1)")
print("___________________________________________________________________________________________________")
# Out:
#     p  q          AIC          BIC
# 0   1  0  5221.545663  5247.228079
# 1   1  1  5119.267896  5150.086795
# 2   1  2  5121.267896  5157.223278
# 3   1  3  5123.193725  5164.285591
# 4   2  0  5188.060235  5218.879135
# 5   2  1  5121.230269  5157.185651
# 6   2  2  5122.303933  5163.395799
# 7   2  3  5121.586421  5167.814770
# 8   3  0  5178.395006  5214.350388
# 9   3  1  5123.230269  5164.322135
# 10  3  2  5124.303933  5170.532282
# 11  3  3  5123.558188  5174.923020
#
# The analysis of the AIC and BIC components shows that this time serie can be modeled with GARCH.
# Best model => GARCH(1,0,1)
# ___________________________________________________________________________________________________

# %%
garch_model = arch_model(df['returns'],mean='AR', vol='Garch', p=1, o=0, q=1, dist='skewt').fit()
garch_model.summary()
# Out:
# Iteration:      1,   Func. Count:      8,   Neg. LLF: 7137.504544679114
# Iteration:      2,   Func. Count:     19,   Neg. LLF: 53180.19574795624
# Iteration:      3,   Func. Count:     29,   Neg. LLF: 77525.07060935994
# Iteration:      4,   Func. Count:     38,   Neg. LLF: 2919.165530836879
# Iteration:      5,   Func. Count:     47,   Neg. LLF: 2622.1156900493074
# Iteration:      6,   Func. Count:     56,   Neg. LLF: 3778.705911442853
# Iteration:      7,   Func. Count:     64,   Neg. LLF: 2554.0355907554217
# Iteration:      8,   Func. Count:     72,   Neg. LLF: 2553.6891838958063
# Iteration:      9,   Func. Count:     80,   Neg. LLF: 2553.636220012596
# Iteration:     10,   Func. Count:     87,   Neg. LLF: 2553.6339583065183
# Iteration:     11,   Func. Count:     94,   Neg. LLF: 2553.63394808779
# Iteration:     12,   Func. Count:    100,   Neg. LLF: 2553.6339480878223
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2553.63394808779
#             Iterations: 12
#             Function evaluations: 100
#             Gradient evaluations: 12
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  AR - GARCH Model Results
# =========================================================================================
# Dep. Variable:                           returns   R-squared:                       0.000
# Mean Model:                                   AR   Adj. R-squared:                  0.000
# Vol Model:                                 GARCH   Log-Likelihood:               -2553.63
# Distribution:      Standardized Skew Student's t   AIC:                           5119.27
# Method:                       Maximum Likelihood   BIC:                           5150.09
#                                                    No. Observations:                 1257
# Date:                           Thu, Dec 29 2022   Df Residuals:                     1256
# Time:                                   19:33:01   Df Model:                            1
#                                  Mean Model
# ===========================================================================
#                  coef    std err          t      P>|t|     95.0% Conf. Int.
# ---------------------------------------------------------------------------
# Const         -0.1718  4.920e-02     -3.492  4.802e-04 [ -0.268,-7.536e-02]
#                              Volatility Model
# ==========================================================================
#                  coef    std err          t      P>|t|    95.0% Conf. Int.
# --------------------------------------------------------------------------
# omega          0.1557  4.841e-02      3.216  1.300e-03 [6.080e-02,  0.251]
# alpha[1]       0.1276  2.601e-02      4.904  9.379e-07 [7.659e-02,  0.179]
# beta[1]        0.8436  2.699e-02     31.252 2.070e-214   [  0.791,  0.897]
#                                 Distribution
# ===========================================================================
#                  coef    std err          t      P>|t|     95.0% Conf. Int.
# ---------------------------------------------------------------------------
# eta            5.8358      0.928      6.287  3.239e-10    [  4.016,  7.655]
# lambda         0.0290  3.917e-02      0.741      0.459 [-4.776e-02,  0.106]
# ===========================================================================
#
# Covariance estimator: robust
# """

# %%
######################################################## FORECASTS ######################################################################
##################################################### CONSTANT WINDOW ###################################################################

df_const_returns = df[df['date'] <= datetime.datetime.strptime("2022-08-31", '%Y-%m-%d')]

# Use previous ARIMA(2, 0, 2) to predict mu 
predicted_mu = arma_model.forecast(horizon=20).values[0]

# Use previous GARCH(1,1) to predict the variance
pred = garch_model.forecast(horizon=20).variance.dropna().iloc[0][:]
garch_mu = garch_model.forecast(horizon=20).mean.dropna().iloc[0][:]

#Use the variance determined by GARCH model and mu determined by ARMA model to create forecasts
fixed_forecast = predicted_mu + [random.normalvariate(garch_mu[i], pred[i]) for i in range(len(pred))]

print(fixed_forecast)
# Out:
# [ 6.11582375 -1.29815107 -8.48677325 -9.3818502  -0.93007449 -6.35596196
#  -1.6311903   2.0060526   0.85466686  8.19958291  1.2780296  -5.70134962
#  -4.74143132 -8.91316888 -0.37363656  1.32251701 -6.87417874  2.31211458
#   5.52952064  2.46242148]

# %%
######################################################## FORECASTS PLOT & RMSE ######################################################################

x_axis = df[df['date'] > datetime.datetime.strptime("2022-08-31", '%Y-%m-%d')]
x_axis = x_axis[x_axis['date'] <= datetime.datetime.strptime("2022-09-29", '%Y-%m-%d')]
x_axis = x_axis['date']

real_value = df[df['date'] > datetime.datetime.strptime("2022-08-31", '%Y-%m-%d')]
real_value = real_value[real_value['date'] <= datetime.datetime.strptime("2022-09-29", '%Y-%m-%d')]
real_value = real_value['returns']

plt.plot(x_axis, fixed_forecast, label = 'Forecast returns fixed')
plt.plot(x_axis, real_value, label = 'Real returns')
plt.legend()
plt.title('Forecast with a fixed window with a GARCH(1, 1) model')
plt.show()

#Compute the error between the model and the real values
RMSE = np.sum(np.power(fixed_forecast-real_value,2))
print(f"The root mean squared errors are of {RMSE}")
print("_________________________________________________________________________________________________")
# Out:
# The root mean squared errors are of 515.8112538189553
# _________________________________________________________________________________________________

# %%
######################################################## FORECASTS ######################################################################
##################################################### EXPANDING WINDOW ##################################################################
first_split_date = datetime.datetime.strptime("2022-08-31", '%Y-%m-%d')
index_ = df.index[df["date"]==first_split_date].tolist()[0]


expanding_forecast = []
for i in range(20):
    # Use the data to predict mu
    df_const_returns = df[df['date'] <= df["date"][index_ + i]]
    arma_model = sm.tsa.arima.ARIMA(df_const_returns['returns'], order=(2, 0, 2)).fit()
    predicted_mu = arma_model.forecast(horizon=1).values[0] #Can take any value as it is constant
    
    #Fit GARCH model
    garch_model = arch_model(df_const_returns['returns'], vol='Garch', p=1, o=0, q=1, dist='skewt').fit()
    pred = garch_model.forecast(horizon=1).variance.dropna().iloc[0][0]
    
    expanding_forecast.append(predicted_mu + random.normalvariate(0, pred))
#results in the next cell
# Out:
# Iteration:      1,   Func. Count:      8,   Neg. LLF: 6538.062733810812
# Iteration:      2,   Func. Count:     19,   Neg. LLF: 50282.27259928796
# Iteration:      3,   Func. Count:     29,   Neg. LLF: 69676.91710703436
# Iteration:      4,   Func. Count:     38,   Neg. LLF: 2798.1414206296204
# Iteration:      5,   Func. Count:     47,   Neg. LLF: 2378.922426716774
# Iteration:      6,   Func. Count:     56,   Neg. LLF: 3442.282237353613
# Iteration:      7,   Func. Count:     64,   Neg. LLF: 2356.527517563898
# Iteration:      8,   Func. Count:     71,   Neg. LLF: 2356.4953445011292
# Iteration:      9,   Func. Count:     78,   Neg. LLF: 2356.4969010574723
# Iteration:     10,   Func. Count:     86,   Neg. LLF: 2356.488863135737
# Iteration:     11,   Func. Count:     93,   Neg. LLF: 2356.4885647392657
# Iteration:     12,   Func. Count:    100,   Neg. LLF: 2356.488470402919
# Iteration:     13,   Func. Count:    106,   Neg. LLF: 2356.488470402961
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2356.488470402919
#             Iterations: 13
#             Function evaluations: 106
#             Gradient evaluations: 13
# Iteration:      1,   Func. Count:      8,   Neg. LLF: 6540.400523120936
# Iteration:      2,   Func. Count:     19,   Neg. LLF: 50067.434734595576
# Iteration:      3,   Func. Count:     29,   Neg. LLF: 39417.70886595197
# Iteration:      4,   Func. Count:     38,   Neg. LLF: 2818.8435578529725
# Iteration:      5,   Func. Count:     47,   Neg. LLF: 2398.907833312233
# Iteration:      6,   Func. Count:     56,   Neg. LLF: 3437.2922482465046
# Iteration:      7,   Func. Count:     64,   Neg. LLF: 2357.9426909219897
# Iteration:      8,   Func. Count:     71,   Neg. LLF: 2357.9137646399968
# Iteration:      9,   Func. Count:     78,   Neg. LLF: 2357.912469121213
# Iteration:     10,   Func. Count:     86,   Neg. LLF: 2357.900341105432
# Iteration:     11,   Func. Count:     93,   Neg. LLF: 2357.8999872586874
# Iteration:     12,   Func. Count:    100,   Neg. LLF: 2357.8998447372906
# Iteration:     13,   Func. Count:    106,   Neg. LLF: 2357.8998447372555
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2357.8998447372906
#             Iterations: 13
#             Function evaluations: 106
#             Gradient evaluations: 13
# Iteration:      1,   Func. Count:      8,   Neg. LLF: 6542.825427257751
# Iteration:      2,   Func. Count:     19,   Neg. LLF: 49988.79977689971
# Iteration:      3,   Func. Count:     29,   Neg. LLF: 39343.22946879884
# Iteration:      4,   Func. Count:     38,   Neg. LLF: 2808.7286125866344
# Iteration:      5,   Func. Count:     47,   Neg. LLF: 2361.071318605885
# Iteration:      6,   Func. Count:     55,   Neg. LLF: 3501.439472934858
# Iteration:      7,   Func. Count:     63,   Neg. LLF: 2360.0554839466113
# Iteration:      8,   Func. Count:     71,   Neg. LLF: 2359.9731428855066
# Iteration:      9,   Func. Count:     79,   Neg. LLF: 2359.8768834803136
# Iteration:     10,   Func. Count:     86,   Neg. LLF: 2359.8762448837174
# Iteration:     11,   Func. Count:     93,   Neg. LLF: 2359.8756973412155
# Iteration:     12,   Func. Count:    100,   Neg. LLF: 2359.8756769883707
# Iteration:     13,   Func. Count:    106,   Neg. LLF: 2359.8756769883744
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2359.8756769883707
#             Iterations: 13
#             Function evaluations: 106
#             Gradient evaluations: 13
# Iteration:      1,   Func. Count:      8,   Neg. LLF: 6542.396367239206
# Iteration:      2,   Func. Count:     19,   Neg. LLF: 50238.20686292171
# Iteration:      3,   Func. Count:     29,   Neg. LLF: 39368.77271157326
# Iteration:      4,   Func. Count:     38,   Neg. LLF: 2804.7115798674586
# Iteration:      5,   Func. Count:     47,   Neg. LLF: 2488.9752621044345
# Iteration:      6,   Func. Count:     56,   Neg. LLF: 3437.5488539403873
# Iteration:      7,   Func. Count:     64,   Neg. LLF: 2361.554578439986
# Iteration:      8,   Func. Count:     71,   Neg. LLF: 2361.5188208259606
# Iteration:      9,   Func. Count:     78,   Neg. LLF: 2361.517143330798
# Iteration:     10,   Func. Count:     86,   Neg. LLF: 2361.511477345956
# Iteration:     11,   Func. Count:     93,   Neg. LLF: 2361.511209785205
# Iteration:     12,   Func. Count:    100,   Neg. LLF: 2361.5111124709856
# Iteration:     13,   Func. Count:    106,   Neg. LLF: 2361.5111124709692
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2361.5111124709856
#             Iterations: 13
#             Function evaluations: 106
#             Gradient evaluations: 13
# Iteration:      1,   Func. Count:      8,   Neg. LLF: 6547.9961030087425
# Iteration:      2,   Func. Count:     19,   Neg. LLF: 50157.48149595633
# Iteration:      3,   Func. Count:     29,   Neg. LLF: 72365.58466445573
# Iteration:      4,   Func. Count:     38,   Neg. LLF: 2836.148251871411
# Iteration:      5,   Func. Count:     47,   Neg. LLF: 2454.5864736225403
# Iteration:      6,   Func. Count:     56,   Neg. LLF: 3438.0930393280846
# Iteration:      7,   Func. Count:     64,   Neg. LLF: 2362.9793487349452
# Iteration:      8,   Func. Count:     71,   Neg. LLF: 2362.9417212060125
# Iteration:      9,   Func. Count:     78,   Neg. LLF: 2362.941905793265
# Iteration:     10,   Func. Count:     86,   Neg. LLF: 2362.936057823376
# Iteration:     11,   Func. Count:     93,   Neg. LLF: 2362.9357837240404
# Iteration:     12,   Func. Count:    100,   Neg. LLF: 2362.935697285753
# Iteration:     13,   Func. Count:    106,   Neg. LLF: 2362.935697285733
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2362.935697285753
#             Iterations: 13
#             Function evaluations: 106
#             Gradient evaluations: 13
# Iteration:      1,   Func. Count:      8,   Neg. LLF: 6546.4378559534
# Iteration:      2,   Func. Count:     19,   Neg. LLF: 50261.91226410134
# Iteration:      3,   Func. Count:     29,   Neg. LLF: 71531.25154951643
# Iteration:      4,   Func. Count:     38,   Neg. LLF: 2829.1515333591915
# Iteration:      5,   Func. Count:     47,   Neg. LLF: 4009.1090573512242
# Iteration:      6,   Func. Count:     57,   Neg. LLF: 2367.1482927831803
# Iteration:      7,   Func. Count:     65,   Neg. LLF: 2364.639169067299
# Iteration:      8,   Func. Count:     72,   Neg. LLF: 2364.6288662860115
# Iteration:      9,   Func. Count:     79,   Neg. LLF: 2364.627686730799
# Iteration:     10,   Func. Count:     86,   Neg. LLF: 2364.6254070991713
# Iteration:     11,   Func. Count:     93,   Neg. LLF: 2364.6252173445364
# Iteration:     12,   Func. Count:    100,   Neg. LLF: 2364.625173462485
# Iteration:     13,   Func. Count:    106,   Neg. LLF: 2364.625173462424
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2364.625173462485
#             Iterations: 13
#             Function evaluations: 106
#             Gradient evaluations: 13
# Iteration:      1,   Func. Count:      8,   Neg. LLF: 6560.591005699802
# Iteration:      2,   Func. Count:     19,   Neg. LLF: 50544.7007560597
# Iteration:      3,   Func. Count:     29,   Neg. LLF: 39423.06424510908
# Iteration:      4,   Func. Count:     38,   Neg. LLF: 2829.818483751985
# Iteration:      5,   Func. Count:     47,   Neg. LLF: 2499.333596214843
# Iteration:      6,   Func. Count:     56,   Neg. LLF: 2639.2211497043245
# Iteration:      7,   Func. Count:     64,   Neg. LLF: 2366.725403579002
# Iteration:      8,   Func. Count:     71,   Neg. LLF: 2366.692681685117
# Iteration:      9,   Func. Count:     78,   Neg. LLF: 2366.6913128367505
# Iteration:     10,   Func. Count:     86,   Neg. LLF: 2366.684785187058
# Iteration:     11,   Func. Count:     93,   Neg. LLF: 2366.684556599849
# Iteration:     12,   Func. Count:    100,   Neg. LLF: 2366.6844646335658
# Iteration:     13,   Func. Count:    106,   Neg. LLF: 2366.684464633552
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2366.6844646335658
#             Iterations: 13
#             Function evaluations: 106
#             Gradient evaluations: 13
# Iteration:      1,   Func. Count:      8,   Neg. LLF: 6563.111765847081
# Iteration:      2,   Func. Count:     19,   Neg. LLF: 51473.258572202925
# Iteration:      3,   Func. Count:     29,   Neg. LLF: 69582.77113391446
# Iteration:      4,   Func. Count:     38,   Neg. LLF: 2742.524021079278
# Iteration:      5,   Func. Count:     47,   Neg. LLF: 2464.490072046327
# Iteration:      6,   Func. Count:     56,   Neg. LLF: 3468.9932660738127
# Iteration:      7,   Func. Count:     64,   Neg. LLF: 2370.79179792305
# Iteration:      8,   Func. Count:     71,   Neg. LLF: 2370.7536842622053
# Iteration:      9,   Func. Count:     78,   Neg. LLF: 2370.749077605029
# Iteration:     10,   Func. Count:     85,   Neg. LLF: 2370.744449829215
# Iteration:     11,   Func. Count:     92,   Neg. LLF: 2370.7441516175736
# Iteration:     12,   Func. Count:     99,   Neg. LLF: 2370.744028469311
# Iteration:     13,   Func. Count:    105,   Neg. LLF: 2370.744028469289
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2370.744028469311
#             Iterations: 13
#             Function evaluations: 105
#             Gradient evaluations: 13
# Iteration:      1,   Func. Count:      8,   Neg. LLF: 6612.641547362227
# Iteration:      2,   Func. Count:     19,   Neg. LLF: 50530.70245519042
# Iteration:      3,   Func. Count:     29,   Neg. LLF: 67612.95392713933
# Iteration:      4,   Func. Count:     38,   Neg. LLF: 2759.5359788723003
# Iteration:      5,   Func. Count:     47,   Neg. LLF: 2423.3980310300317
# Iteration:      6,   Func. Count:     56,   Neg. LLF: 3488.971399336254
# Iteration:      7,   Func. Count:     64,   Neg. LLF: 2376.402339538475
# Iteration:      8,   Func. Count:     71,   Neg. LLF: 2376.3435807593623
# Iteration:      9,   Func. Count:     78,   Neg. LLF: 2376.351806189648
# Iteration:     10,   Func. Count:     86,   Neg. LLF: 2376.3367686371284
# Iteration:     11,   Func. Count:     93,   Neg. LLF: 2376.3363042163605
# Iteration:     12,   Func. Count:    100,   Neg. LLF: 2376.3361547430277
# Iteration:     13,   Func. Count:    106,   Neg. LLF: 2376.3361547430127
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2376.3361547430277
#             Iterations: 13
#             Function evaluations: 106
#             Gradient evaluations: 13
# Iteration:      1,   Func. Count:      8,   Neg. LLF: 6613.004722717655
# Iteration:      2,   Func. Count:     19,   Neg. LLF: 50445.901674785826
# Iteration:      3,   Func. Count:     29,   Neg. LLF: 69605.39083832238
# Iteration:      4,   Func. Count:     38,   Neg. LLF: 2774.7540546310156
# Iteration:      5,   Func. Count:     47,   Neg. LLF: 2433.454435374222
# Iteration:      6,   Func. Count:     56,   Neg. LLF: 3500.2700692698604
# Iteration:      7,   Func. Count:     64,   Neg. LLF: 2378.3983568118415
# Iteration:      8,   Func. Count:     71,   Neg. LLF: 2378.333486671203
# Iteration:      9,   Func. Count:     78,   Neg. LLF: 2378.3692407898698
# Iteration:     10,   Func. Count:     86,   Neg. LLF: 2378.2216020089695
# Iteration:     11,   Func. Count:     93,   Neg. LLF: 2378.221031703987
# Iteration:     12,   Func. Count:    100,   Neg. LLF: 2378.220845469612
# Iteration:     13,   Func. Count:    107,   Neg. LLF: 2378.2208171751754
# Iteration:     14,   Func. Count:    114,   Neg. LLF: 2378.2208160500286
# Iteration:     15,   Func. Count:    120,   Neg. LLF: 2378.2208160500345
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2378.2208160500286
#             Iterations: 15
#             Function evaluations: 120
#             Gradient evaluations: 15
# Iteration:      1,   Func. Count:      8,   Neg. LLF: 6628.7493470798
# Iteration:      2,   Func. Count:     19,   Neg. LLF: 50402.03207632573
# Iteration:      3,   Func. Count:     29,   Neg. LLF: 67666.36479014375
# Iteration:      4,   Func. Count:     38,   Neg. LLF: 2766.708106982584
# Iteration:      5,   Func. Count:     47,   Neg. LLF: 2433.8533467414595
# Iteration:      6,   Func. Count:     56,   Neg. LLF: 3504.7175577405437
# Iteration:      7,   Func. Count:     64,   Neg. LLF: 2380.62987727755
# Iteration:      8,   Func. Count:     71,   Neg. LLF: 2380.5556409953324
# Iteration:      9,   Func. Count:     78,   Neg. LLF: 2380.589042680078
# Iteration:     10,   Func. Count:     86,   Neg. LLF: 2380.499216671933
# Iteration:     11,   Func. Count:     93,   Neg. LLF: 2380.498774440336
# Iteration:     12,   Func. Count:    100,   Neg. LLF: 2380.4985867422947
# Iteration:     13,   Func. Count:    107,   Neg. LLF: 2380.49857786356
# Iteration:     14,   Func. Count:    113,   Neg. LLF: 2380.4985778636133
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2380.49857786356
#             Iterations: 14
#             Function evaluations: 113
#             Gradient evaluations: 14
# Iteration:      1,   Func. Count:      8,   Neg. LLF: 6638.733991674282
# Iteration:      2,   Func. Count:     19,   Neg. LLF: 50258.61858393786
# Iteration:      3,   Func. Count:     29,   Neg. LLF: 85623.05403699442
# Iteration:      4,   Func. Count:     38,   Neg. LLF: 2762.3014039617415
# Iteration:      5,   Func. Count:     47,   Neg. LLF: 2435.440716293535
# Iteration:      6,   Func. Count:     56,   Neg. LLF: 3508.675486593891
# Iteration:      7,   Func. Count:     64,   Neg. LLF: 2382.581470427579
# Iteration:      8,   Func. Count:     71,   Neg. LLF: 2382.4948223607344
# Iteration:      9,   Func. Count:     78,   Neg. LLF: 2382.522398518051
# Iteration:     10,   Func. Count:     86,   Neg. LLF: 2382.4632963589247
# Iteration:     11,   Func. Count:     93,   Neg. LLF: 2382.4629080855275
# Iteration:     12,   Func. Count:    100,   Neg. LLF: 2382.4627233815563
# Iteration:     13,   Func. Count:    107,   Neg. LLF: 2382.46272264609
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2382.46272264609
#             Iterations: 13
#             Function evaluations: 107
#             Gradient evaluations: 13
# Iteration:      1,   Func. Count:      8,   Neg. LLF: 6633.099762227586
# Iteration:      2,   Func. Count:     19,   Neg. LLF: 50666.34640889939
# Iteration:      3,   Func. Count:     29,   Neg. LLF: 72918.40140142108
# Iteration:      4,   Func. Count:     38,   Neg. LLF: 2787.400115169674
# Iteration:      5,   Func. Count:     47,   Neg. LLF: 2435.22331187304
# Iteration:      6,   Func. Count:     56,   Neg. LLF: 3505.7095554554485
# Iteration:      7,   Func. Count:     64,   Neg. LLF: 2384.852711815338
# Iteration:      8,   Func. Count:     71,   Neg. LLF: 2384.786827817064
# Iteration:      9,   Func. Count:     78,   Neg. LLF: 2384.799538828059
# Iteration:     10,   Func. Count:     86,   Neg. LLF: 2384.778426113676
# Iteration:     11,   Func. Count:     93,   Neg. LLF: 2384.7780444697864
# Iteration:     12,   Func. Count:    100,   Neg. LLF: 2384.7779079841375
# Iteration:     13,   Func. Count:    106,   Neg. LLF: 2384.777907984133
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2384.7779079841375
#             Iterations: 13
#             Function evaluations: 106
#             Gradient evaluations: 13
# Iteration:      1,   Func. Count:      8,   Neg. LLF: 6632.61251825877
# Iteration:      2,   Func. Count:     19,   Neg. LLF: 50724.710601049315
# Iteration:      3,   Func. Count:     29,   Neg. LLF: 38605.72267187138
# Iteration:      4,   Func. Count:     38,   Neg. LLF: 2820.8901537276324
# Iteration:      5,   Func. Count:     47,   Neg. LLF: 2436.109593853493
# Iteration:      6,   Func. Count:     56,   Neg. LLF: 3501.5007173453064
# Iteration:      7,   Func. Count:     64,   Neg. LLF: 2386.7251864096506
# Iteration:      8,   Func. Count:     71,   Neg. LLF: 2386.6771281395677
# Iteration:      9,   Func. Count:     78,   Neg. LLF: 2386.697477765723
# Iteration:     10,   Func. Count:     86,   Neg. LLF: 2386.6653785336184
# Iteration:     11,   Func. Count:     93,   Neg. LLF: 2386.6649484447635
# Iteration:     12,   Func. Count:    100,   Neg. LLF: 2386.6647790185098
# Iteration:     13,   Func. Count:    106,   Neg. LLF: 2386.664779018483
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2386.6647790185098
#             Iterations: 13
#             Function evaluations: 106
#             Gradient evaluations: 13
# Iteration:      1,   Func. Count:      8,   Neg. LLF: 6646.500012779068
# Iteration:      2,   Func. Count:     19,   Neg. LLF: 50814.0947211419
# Iteration:      3,   Func. Count:     29,   Neg. LLF: 78538.81639151601
# Iteration:      4,   Func. Count:     38,   Neg. LLF: 2811.8601230752197
# Iteration:      5,   Func. Count:     47,   Neg. LLF: 2436.8741670611944
# Iteration:      6,   Func. Count:     56,   Neg. LLF: 3509.1789524179558
# Iteration:      7,   Func. Count:     64,   Neg. LLF: 2389.077144607778
# Iteration:      8,   Func. Count:     71,   Neg. LLF: 2389.0315053977806
# Iteration:      9,   Func. Count:     78,   Neg. LLF: 2389.0430546380935
# Iteration:     10,   Func. Count:     86,   Neg. LLF: 2389.0202835973573
# Iteration:     11,   Func. Count:     93,   Neg. LLF: 2389.019929540929
# Iteration:     12,   Func. Count:    100,   Neg. LLF: 2389.019789369354
# Iteration:     13,   Func. Count:    106,   Neg. LLF: 2389.019789369339
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2389.019789369354
#             Iterations: 13
#             Function evaluations: 106
#             Gradient evaluations: 13
# Iteration:      1,   Func. Count:      8,   Neg. LLF: 6653.7439182265225
# Iteration:      2,   Func. Count:     19,   Neg. LLF: 50638.527943137415
# Iteration:      3,   Func. Count:     29,   Neg. LLF: 38908.839320863124
# Iteration:      4,   Func. Count:     38,   Neg. LLF: 2814.143486270491
# Iteration:      5,   Func. Count:     47,   Neg. LLF: 2401.3299854770817
# Iteration:      6,   Func. Count:     55,   Neg. LLF: 3516.2440396503926
# Iteration:      7,   Func. Count:     63,   Neg. LLF: 2390.784271264674
# Iteration:      8,   Func. Count:     70,   Neg. LLF: 2390.790859799598
# Iteration:      9,   Func. Count:     78,   Neg. LLF: 2390.7862561968177
# Iteration:     10,   Func. Count:     86,   Neg. LLF: 2390.754254715157
# Iteration:     11,   Func. Count:     93,   Neg. LLF: 2390.753606643834
# Iteration:     12,   Func. Count:    100,   Neg. LLF: 2390.7536018538767
# Iteration:     13,   Func. Count:    106,   Neg. LLF: 2390.7536018538954
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2390.7536018538767
#             Iterations: 13
#             Function evaluations: 106
#             Gradient evaluations: 13
# Iteration:      1,   Func. Count:      8,   Neg. LLF: 6663.253433200694
# Iteration:      2,   Func. Count:     19,   Neg. LLF: 50447.98504822649
# Iteration:      3,   Func. Count:     29,   Neg. LLF: 39093.19438549885
# Iteration:      4,   Func. Count:     38,   Neg. LLF: 2807.4149195337836
# Iteration:      5,   Func. Count:     47,   Neg. LLF: 2456.0046241895293
# Iteration:      6,   Func. Count:     56,   Neg. LLF: 3513.5831452249417
# Iteration:      7,   Func. Count:     64,   Neg. LLF: 2392.8905736230618
# Iteration:      8,   Func. Count:     71,   Neg. LLF: 2392.8286502129704
# Iteration:      9,   Func. Count:     78,   Neg. LLF: 2392.8287610750676
# Iteration:     10,   Func. Count:     86,   Neg. LLF: 2392.822200173105
# Iteration:     11,   Func. Count:     93,   Neg. LLF: 2392.8218905087997
# Iteration:     12,   Func. Count:    100,   Neg. LLF: 2392.8217849280472
# Iteration:     13,   Func. Count:    106,   Neg. LLF: 2392.8217849280427
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2392.8217849280472
#             Iterations: 13
#             Function evaluations: 106
#             Gradient evaluations: 13
# Iteration:      1,   Func. Count:      8,   Neg. LLF: 6666.974158158049
# Iteration:      2,   Func. Count:     19,   Neg. LLF: 50451.71832340812
# Iteration:      3,   Func. Count:     29,   Neg. LLF: 70527.40035794154
# Iteration:      4,   Func. Count:     38,   Neg. LLF: 2827.465219147841
# Iteration:      5,   Func. Count:     47,   Neg. LLF: 19557.255699283563
# Iteration:      6,   Func. Count:     57,   Neg. LLF: 2405.6956912084465
# Iteration:      7,   Func. Count:     65,   Neg. LLF: 2394.4627633253067
# Iteration:      8,   Func. Count:     72,   Neg. LLF: 2394.347016257745
# Iteration:      9,   Func. Count:     79,   Neg. LLF: 2394.339350777619
# Iteration:     10,   Func. Count:     86,   Neg. LLF: 2394.3300622253532
# Iteration:     11,   Func. Count:     93,   Neg. LLF: 2394.3297771773723
# Iteration:     12,   Func. Count:    100,   Neg. LLF: 2394.3296973866663
# Iteration:     13,   Func. Count:    107,   Neg. LLF: 2394.3296779389766
# Iteration:     14,   Func. Count:    113,   Neg. LLF: 2394.3296779389875
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2394.3296779389766
#             Iterations: 14
#             Function evaluations: 113
#             Gradient evaluations: 14
# Iteration:      1,   Func. Count:      8,   Neg. LLF: 6670.970651150696
# Iteration:      2,   Func. Count:     19,   Neg. LLF: 50193.04617312898
# Iteration:      3,   Func. Count:     29,   Neg. LLF: 76411.62178152982
# Iteration:      4,   Func. Count:     38,   Neg. LLF: 2861.845443954102
# Iteration:      5,   Func. Count:     47,   Neg. LLF: 50895.33420637356
# Iteration:      6,   Func. Count:     57,   Neg. LLF: 2406.1944213329098
# Iteration:      7,   Func. Count:     65,   Neg. LLF: 2395.925827606088
# Iteration:      8,   Func. Count:     72,   Neg. LLF: 2395.8119926122745
# Iteration:      9,   Func. Count:     79,   Neg. LLF: 2395.805624399443
# Iteration:     10,   Func. Count:     86,   Neg. LLF: 2395.7976143973
# Iteration:     11,   Func. Count:     93,   Neg. LLF: 2395.7973050819023
# Iteration:     12,   Func. Count:    100,   Neg. LLF: 2395.797215195891
# Iteration:     13,   Func. Count:    107,   Neg. LLF: 2395.7971942509635
# Iteration:     14,   Func. Count:    113,   Neg. LLF: 2395.7971942509776
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2395.7971942509635
#             Iterations: 14
#             Function evaluations: 113
#             Gradient evaluations: 14
# Iteration:      1,   Func. Count:      8,   Neg. LLF: 6676.1208432752655
# Iteration:      2,   Func. Count:     19,   Neg. LLF: 50332.12089033061
# Iteration:      3,   Func. Count:     29,   Neg. LLF: 39212.645679558176
# Iteration:      4,   Func. Count:     38,   Neg. LLF: 2853.01261211387
# Iteration:      5,   Func. Count:     47,   Neg. LLF: 19617.78858848895
# Iteration:      6,   Func. Count:     57,   Neg. LLF: 2407.9488359855613
# Iteration:      7,   Func. Count:     65,   Neg. LLF: 2397.82934195134
# Iteration:      8,   Func. Count:     72,   Neg. LLF: 2397.7212099564886
# Iteration:      9,   Func. Count:     79,   Neg. LLF: 2397.712923122597
# Iteration:     10,   Func. Count:     86,   Neg. LLF: 2397.705974292602
# Iteration:     11,   Func. Count:     93,   Neg. LLF: 2397.705694783579
# Iteration:     12,   Func. Count:    100,   Neg. LLF: 2397.705606008439
# Iteration:     13,   Func. Count:    107,   Neg. LLF: 2397.705588550999
# Iteration:     14,   Func. Count:    113,   Neg. LLF: 2397.7055885510104
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2397.705588550999
#             Iterations: 14
#             Function evaluations: 113
#             Gradient evaluations: 14

# %%
######################################################## FORECASTS PLOT & RMSE ######################################################################

plt.plot(x_axis, expanding_forecast, label = 'Forecast returns')
plt.plot(x_axis, real_value, label = 'Real returns')
plt.legend()
plt.title('Forecast with an expanding window with a GARCH(1, 1) model')
plt.show()

#RMSE
RMSE = np.sum(np.power(expanding_forecast-real_value,2))
print(f"The root mean squared errors are of {RMSE}")
print("_________________________________________________________________________________________________")
# Out:
# The root mean squared errors are of 390.34707116039743
# _________________________________________________________________________________________________

# %%
######################################################## FORECASTS ######################################################################
##################################################### RECURSIVE WINDOW ##################################################################

last_date = datetime.datetime.strptime("2022-08-31", '%Y-%m-%d')
index_ = df.index[df["date"]==last_date].tolist()[0]
first_date = datetime.datetime.strptime("2022-01-03", '%Y-%m-%d')
index_2 = df.index[df["date"]==first_date].tolist()[0]

recursive_forecast = []
for i in range(20):
    df_const_returns = df[df['date'] <= df["date"][index_ + i]]
    df_const_returns = df_const_returns[df_const_returns['date'] >= df["date"][index_2 + i]]

    # Use the data to predict mu
    df_const_returns = df[df['date'] <= df["date"][index_ + i]]
    arma_model = sm.tsa.arima.ARIMA(df_const_returns['returns'], order=(2, 0, 2)).fit()
    predicted_mu = arma_model.forecast(horizon=1).values[0]   #Can take any value as it is constant

    #Use GARCH model to predict epsilon
    garch_model = arch_model(df_const_returns['returns'], vol='Garch', p=1, o=0, q=1, dist='skewt').fit() #Skewed Student since we're using financial data
    pred = garch_model.forecast(horizon=1).variance.dropna().iloc[0][0]
    recursive_forecast.append(predicted_mu + random.normalvariate(0, pred))
# Out:
# Iteration:      1,   Func. Count:      8,   Neg. LLF: 6538.062733810812
# Iteration:      2,   Func. Count:     19,   Neg. LLF: 50282.27259928796
# Iteration:      3,   Func. Count:     29,   Neg. LLF: 69676.91710703436
# Iteration:      4,   Func. Count:     38,   Neg. LLF: 2798.1414206296204
# Iteration:      5,   Func. Count:     47,   Neg. LLF: 2378.922426716774
# Iteration:      6,   Func. Count:     56,   Neg. LLF: 3442.282237353613
# Iteration:      7,   Func. Count:     64,   Neg. LLF: 2356.527517563898
# Iteration:      8,   Func. Count:     71,   Neg. LLF: 2356.4953445011292
# Iteration:      9,   Func. Count:     78,   Neg. LLF: 2356.4969010574723
# Iteration:     10,   Func. Count:     86,   Neg. LLF: 2356.488863135737
# Iteration:     11,   Func. Count:     93,   Neg. LLF: 2356.4885647392657
# Iteration:     12,   Func. Count:    100,   Neg. LLF: 2356.488470402919
# Iteration:     13,   Func. Count:    106,   Neg. LLF: 2356.488470402961
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2356.488470402919
#             Iterations: 13
#             Function evaluations: 106
#             Gradient evaluations: 13
# Iteration:      1,   Func. Count:      8,   Neg. LLF: 6540.400523120936
# Iteration:      2,   Func. Count:     19,   Neg. LLF: 50067.434734595576
# Iteration:      3,   Func. Count:     29,   Neg. LLF: 39417.70886595197
# Iteration:      4,   Func. Count:     38,   Neg. LLF: 2818.8435578529725
# Iteration:      5,   Func. Count:     47,   Neg. LLF: 2398.907833312233
# Iteration:      6,   Func. Count:     56,   Neg. LLF: 3437.2922482465046
# Iteration:      7,   Func. Count:     64,   Neg. LLF: 2357.9426909219897
# Iteration:      8,   Func. Count:     71,   Neg. LLF: 2357.9137646399968
# Iteration:      9,   Func. Count:     78,   Neg. LLF: 2357.912469121213
# Iteration:     10,   Func. Count:     86,   Neg. LLF: 2357.900341105432
# Iteration:     11,   Func. Count:     93,   Neg. LLF: 2357.8999872586874
# Iteration:     12,   Func. Count:    100,   Neg. LLF: 2357.8998447372906
# Iteration:     13,   Func. Count:    106,   Neg. LLF: 2357.8998447372555
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2357.8998447372906
#             Iterations: 13
#             Function evaluations: 106
#             Gradient evaluations: 13
# Iteration:      1,   Func. Count:      8,   Neg. LLF: 6542.825427257751
# Iteration:      2,   Func. Count:     19,   Neg. LLF: 49988.79977689971
# Iteration:      3,   Func. Count:     29,   Neg. LLF: 39343.22946879884
# Iteration:      4,   Func. Count:     38,   Neg. LLF: 2808.7286125866344
# Iteration:      5,   Func. Count:     47,   Neg. LLF: 2361.071318605885
# Iteration:      6,   Func. Count:     55,   Neg. LLF: 3501.439472934858
# Iteration:      7,   Func. Count:     63,   Neg. LLF: 2360.0554839466113
# Iteration:      8,   Func. Count:     71,   Neg. LLF: 2359.9731428855066
# Iteration:      9,   Func. Count:     79,   Neg. LLF: 2359.8768834803136
# Iteration:     10,   Func. Count:     86,   Neg. LLF: 2359.8762448837174
# Iteration:     11,   Func. Count:     93,   Neg. LLF: 2359.8756973412155
# Iteration:     12,   Func. Count:    100,   Neg. LLF: 2359.8756769883707
# Iteration:     13,   Func. Count:    106,   Neg. LLF: 2359.8756769883744
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2359.8756769883707
#             Iterations: 13
#             Function evaluations: 106
#             Gradient evaluations: 13
# Iteration:      1,   Func. Count:      8,   Neg. LLF: 6542.396367239206
# Iteration:      2,   Func. Count:     19,   Neg. LLF: 50238.20686292171
# Iteration:      3,   Func. Count:     29,   Neg. LLF: 39368.77271157326
# Iteration:      4,   Func. Count:     38,   Neg. LLF: 2804.7115798674586
# Iteration:      5,   Func. Count:     47,   Neg. LLF: 2488.9752621044345
# Iteration:      6,   Func. Count:     56,   Neg. LLF: 3437.5488539403873
# Iteration:      7,   Func. Count:     64,   Neg. LLF: 2361.554578439986
# Iteration:      8,   Func. Count:     71,   Neg. LLF: 2361.5188208259606
# Iteration:      9,   Func. Count:     78,   Neg. LLF: 2361.517143330798
# Iteration:     10,   Func. Count:     86,   Neg. LLF: 2361.511477345956
# Iteration:     11,   Func. Count:     93,   Neg. LLF: 2361.511209785205
# Iteration:     12,   Func. Count:    100,   Neg. LLF: 2361.5111124709856
# Iteration:     13,   Func. Count:    106,   Neg. LLF: 2361.5111124709692
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2361.5111124709856
#             Iterations: 13
#             Function evaluations: 106
#             Gradient evaluations: 13
# Iteration:      1,   Func. Count:      8,   Neg. LLF: 6547.9961030087425
# Iteration:      2,   Func. Count:     19,   Neg. LLF: 50157.48149595633
# Iteration:      3,   Func. Count:     29,   Neg. LLF: 72365.58466445573
# Iteration:      4,   Func. Count:     38,   Neg. LLF: 2836.148251871411
# Iteration:      5,   Func. Count:     47,   Neg. LLF: 2454.5864736225403
# Iteration:      6,   Func. Count:     56,   Neg. LLF: 3438.0930393280846
# Iteration:      7,   Func. Count:     64,   Neg. LLF: 2362.9793487349452
# Iteration:      8,   Func. Count:     71,   Neg. LLF: 2362.9417212060125
# Iteration:      9,   Func. Count:     78,   Neg. LLF: 2362.941905793265
# Iteration:     10,   Func. Count:     86,   Neg. LLF: 2362.936057823376
# Iteration:     11,   Func. Count:     93,   Neg. LLF: 2362.9357837240404
# Iteration:     12,   Func. Count:    100,   Neg. LLF: 2362.935697285753
# Iteration:     13,   Func. Count:    106,   Neg. LLF: 2362.935697285733
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2362.935697285753
#             Iterations: 13
#             Function evaluations: 106
#             Gradient evaluations: 13
# Iteration:      1,   Func. Count:      8,   Neg. LLF: 6546.4378559534
# Iteration:      2,   Func. Count:     19,   Neg. LLF: 50261.91226410134
# Iteration:      3,   Func. Count:     29,   Neg. LLF: 71531.25154951643
# Iteration:      4,   Func. Count:     38,   Neg. LLF: 2829.1515333591915
# Iteration:      5,   Func. Count:     47,   Neg. LLF: 4009.1090573512242
# Iteration:      6,   Func. Count:     57,   Neg. LLF: 2367.1482927831803
# Iteration:      7,   Func. Count:     65,   Neg. LLF: 2364.639169067299
# Iteration:      8,   Func. Count:     72,   Neg. LLF: 2364.6288662860115
# Iteration:      9,   Func. Count:     79,   Neg. LLF: 2364.627686730799
# Iteration:     10,   Func. Count:     86,   Neg. LLF: 2364.6254070991713
# Iteration:     11,   Func. Count:     93,   Neg. LLF: 2364.6252173445364
# Iteration:     12,   Func. Count:    100,   Neg. LLF: 2364.625173462485
# Iteration:     13,   Func. Count:    106,   Neg. LLF: 2364.625173462424
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2364.625173462485
#             Iterations: 13
#             Function evaluations: 106
#             Gradient evaluations: 13
# Iteration:      1,   Func. Count:      8,   Neg. LLF: 6560.591005699802
# Iteration:      2,   Func. Count:     19,   Neg. LLF: 50544.7007560597
# Iteration:      3,   Func. Count:     29,   Neg. LLF: 39423.06424510908
# Iteration:      4,   Func. Count:     38,   Neg. LLF: 2829.818483751985
# Iteration:      5,   Func. Count:     47,   Neg. LLF: 2499.333596214843
# Iteration:      6,   Func. Count:     56,   Neg. LLF: 2639.2211497043245
# Iteration:      7,   Func. Count:     64,   Neg. LLF: 2366.725403579002
# Iteration:      8,   Func. Count:     71,   Neg. LLF: 2366.692681685117
# Iteration:      9,   Func. Count:     78,   Neg. LLF: 2366.6913128367505
# Iteration:     10,   Func. Count:     86,   Neg. LLF: 2366.684785187058
# Iteration:     11,   Func. Count:     93,   Neg. LLF: 2366.684556599849
# Iteration:     12,   Func. Count:    100,   Neg. LLF: 2366.6844646335658
# Iteration:     13,   Func. Count:    106,   Neg. LLF: 2366.684464633552
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2366.6844646335658
#             Iterations: 13
#             Function evaluations: 106
#             Gradient evaluations: 13
# Iteration:      1,   Func. Count:      8,   Neg. LLF: 6563.111765847081
# Iteration:      2,   Func. Count:     19,   Neg. LLF: 51473.258572202925
# Iteration:      3,   Func. Count:     29,   Neg. LLF: 69582.77113391446
# Iteration:      4,   Func. Count:     38,   Neg. LLF: 2742.524021079278
# Iteration:      5,   Func. Count:     47,   Neg. LLF: 2464.490072046327
# Iteration:      6,   Func. Count:     56,   Neg. LLF: 3468.9932660738127
# Iteration:      7,   Func. Count:     64,   Neg. LLF: 2370.79179792305
# Iteration:      8,   Func. Count:     71,   Neg. LLF: 2370.7536842622053
# Iteration:      9,   Func. Count:     78,   Neg. LLF: 2370.749077605029
# Iteration:     10,   Func. Count:     85,   Neg. LLF: 2370.744449829215
# Iteration:     11,   Func. Count:     92,   Neg. LLF: 2370.7441516175736
# Iteration:     12,   Func. Count:     99,   Neg. LLF: 2370.744028469311
# Iteration:     13,   Func. Count:    105,   Neg. LLF: 2370.744028469289
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2370.744028469311
#             Iterations: 13
#             Function evaluations: 105
#             Gradient evaluations: 13
# Iteration:      1,   Func. Count:      8,   Neg. LLF: 6612.641547362227
# Iteration:      2,   Func. Count:     19,   Neg. LLF: 50530.70245519042
# Iteration:      3,   Func. Count:     29,   Neg. LLF: 67612.95392713933
# Iteration:      4,   Func. Count:     38,   Neg. LLF: 2759.5359788723003
# Iteration:      5,   Func. Count:     47,   Neg. LLF: 2423.3980310300317
# Iteration:      6,   Func. Count:     56,   Neg. LLF: 3488.971399336254
# Iteration:      7,   Func. Count:     64,   Neg. LLF: 2376.402339538475
# Iteration:      8,   Func. Count:     71,   Neg. LLF: 2376.3435807593623
# Iteration:      9,   Func. Count:     78,   Neg. LLF: 2376.351806189648
# Iteration:     10,   Func. Count:     86,   Neg. LLF: 2376.3367686371284
# Iteration:     11,   Func. Count:     93,   Neg. LLF: 2376.3363042163605
# Iteration:     12,   Func. Count:    100,   Neg. LLF: 2376.3361547430277
# Iteration:     13,   Func. Count:    106,   Neg. LLF: 2376.3361547430127
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2376.3361547430277
#             Iterations: 13
#             Function evaluations: 106
#             Gradient evaluations: 13
# Iteration:      1,   Func. Count:      8,   Neg. LLF: 6613.004722717655
# Iteration:      2,   Func. Count:     19,   Neg. LLF: 50445.901674785826
# Iteration:      3,   Func. Count:     29,   Neg. LLF: 69605.39083832238
# Iteration:      4,   Func. Count:     38,   Neg. LLF: 2774.7540546310156
# Iteration:      5,   Func. Count:     47,   Neg. LLF: 2433.454435374222
# Iteration:      6,   Func. Count:     56,   Neg. LLF: 3500.2700692698604
# Iteration:      7,   Func. Count:     64,   Neg. LLF: 2378.3983568118415
# Iteration:      8,   Func. Count:     71,   Neg. LLF: 2378.333486671203
# Iteration:      9,   Func. Count:     78,   Neg. LLF: 2378.3692407898698
# Iteration:     10,   Func. Count:     86,   Neg. LLF: 2378.2216020089695
# Iteration:     11,   Func. Count:     93,   Neg. LLF: 2378.221031703987
# Iteration:     12,   Func. Count:    100,   Neg. LLF: 2378.220845469612
# Iteration:     13,   Func. Count:    107,   Neg. LLF: 2378.2208171751754
# Iteration:     14,   Func. Count:    114,   Neg. LLF: 2378.2208160500286
# Iteration:     15,   Func. Count:    120,   Neg. LLF: 2378.2208160500345
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2378.2208160500286
#             Iterations: 15
#             Function evaluations: 120
#             Gradient evaluations: 15
# Iteration:      1,   Func. Count:      8,   Neg. LLF: 6628.7493470798
# Iteration:      2,   Func. Count:     19,   Neg. LLF: 50402.03207632573
# Iteration:      3,   Func. Count:     29,   Neg. LLF: 67666.36479014375
# Iteration:      4,   Func. Count:     38,   Neg. LLF: 2766.708106982584
# Iteration:      5,   Func. Count:     47,   Neg. LLF: 2433.8533467414595
# Iteration:      6,   Func. Count:     56,   Neg. LLF: 3504.7175577405437
# Iteration:      7,   Func. Count:     64,   Neg. LLF: 2380.62987727755
# Iteration:      8,   Func. Count:     71,   Neg. LLF: 2380.5556409953324
# Iteration:      9,   Func. Count:     78,   Neg. LLF: 2380.589042680078
# Iteration:     10,   Func. Count:     86,   Neg. LLF: 2380.499216671933
# Iteration:     11,   Func. Count:     93,   Neg. LLF: 2380.498774440336
# Iteration:     12,   Func. Count:    100,   Neg. LLF: 2380.4985867422947
# Iteration:     13,   Func. Count:    107,   Neg. LLF: 2380.49857786356
# Iteration:     14,   Func. Count:    113,   Neg. LLF: 2380.4985778636133
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2380.49857786356
#             Iterations: 14
#             Function evaluations: 113
#             Gradient evaluations: 14
# Iteration:      1,   Func. Count:      8,   Neg. LLF: 6638.733991674282
# Iteration:      2,   Func. Count:     19,   Neg. LLF: 50258.61858393786
# Iteration:      3,   Func. Count:     29,   Neg. LLF: 85623.05403699442
# Iteration:      4,   Func. Count:     38,   Neg. LLF: 2762.3014039617415
# Iteration:      5,   Func. Count:     47,   Neg. LLF: 2435.440716293535
# Iteration:      6,   Func. Count:     56,   Neg. LLF: 3508.675486593891
# Iteration:      7,   Func. Count:     64,   Neg. LLF: 2382.581470427579
# Iteration:      8,   Func. Count:     71,   Neg. LLF: 2382.4948223607344
# Iteration:      9,   Func. Count:     78,   Neg. LLF: 2382.522398518051
# Iteration:     10,   Func. Count:     86,   Neg. LLF: 2382.4632963589247
# Iteration:     11,   Func. Count:     93,   Neg. LLF: 2382.4629080855275
# Iteration:     12,   Func. Count:    100,   Neg. LLF: 2382.4627233815563
# Iteration:     13,   Func. Count:    107,   Neg. LLF: 2382.46272264609
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2382.46272264609
#             Iterations: 13
#             Function evaluations: 107
#             Gradient evaluations: 13
# Iteration:      1,   Func. Count:      8,   Neg. LLF: 6633.099762227586
# Iteration:      2,   Func. Count:     19,   Neg. LLF: 50666.34640889939
# Iteration:      3,   Func. Count:     29,   Neg. LLF: 72918.40140142108
# Iteration:      4,   Func. Count:     38,   Neg. LLF: 2787.400115169674
# Iteration:      5,   Func. Count:     47,   Neg. LLF: 2435.22331187304
# Iteration:      6,   Func. Count:     56,   Neg. LLF: 3505.7095554554485
# Iteration:      7,   Func. Count:     64,   Neg. LLF: 2384.852711815338
# Iteration:      8,   Func. Count:     71,   Neg. LLF: 2384.786827817064
# Iteration:      9,   Func. Count:     78,   Neg. LLF: 2384.799538828059
# Iteration:     10,   Func. Count:     86,   Neg. LLF: 2384.778426113676
# Iteration:     11,   Func. Count:     93,   Neg. LLF: 2384.7780444697864
# Iteration:     12,   Func. Count:    100,   Neg. LLF: 2384.7779079841375
# Iteration:     13,   Func. Count:    106,   Neg. LLF: 2384.777907984133
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2384.7779079841375
#             Iterations: 13
#             Function evaluations: 106
#             Gradient evaluations: 13
# Iteration:      1,   Func. Count:      8,   Neg. LLF: 6632.61251825877
# Iteration:      2,   Func. Count:     19,   Neg. LLF: 50724.710601049315
# Iteration:      3,   Func. Count:     29,   Neg. LLF: 38605.72267187138
# Iteration:      4,   Func. Count:     38,   Neg. LLF: 2820.8901537276324
# Iteration:      5,   Func. Count:     47,   Neg. LLF: 2436.109593853493
# Iteration:      6,   Func. Count:     56,   Neg. LLF: 3501.5007173453064
# Iteration:      7,   Func. Count:     64,   Neg. LLF: 2386.7251864096506
# Iteration:      8,   Func. Count:     71,   Neg. LLF: 2386.6771281395677
# Iteration:      9,   Func. Count:     78,   Neg. LLF: 2386.697477765723
# Iteration:     10,   Func. Count:     86,   Neg. LLF: 2386.6653785336184
# Iteration:     11,   Func. Count:     93,   Neg. LLF: 2386.6649484447635
# Iteration:     12,   Func. Count:    100,   Neg. LLF: 2386.6647790185098
# Iteration:     13,   Func. Count:    106,   Neg. LLF: 2386.664779018483
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2386.6647790185098
#             Iterations: 13
#             Function evaluations: 106
#             Gradient evaluations: 13
# Iteration:      1,   Func. Count:      8,   Neg. LLF: 6646.500012779068
# Iteration:      2,   Func. Count:     19,   Neg. LLF: 50814.0947211419
# Iteration:      3,   Func. Count:     29,   Neg. LLF: 78538.81639151601
# Iteration:      4,   Func. Count:     38,   Neg. LLF: 2811.8601230752197
# Iteration:      5,   Func. Count:     47,   Neg. LLF: 2436.8741670611944
# Iteration:      6,   Func. Count:     56,   Neg. LLF: 3509.1789524179558
# Iteration:      7,   Func. Count:     64,   Neg. LLF: 2389.077144607778
# Iteration:      8,   Func. Count:     71,   Neg. LLF: 2389.0315053977806
# Iteration:      9,   Func. Count:     78,   Neg. LLF: 2389.0430546380935
# Iteration:     10,   Func. Count:     86,   Neg. LLF: 2389.0202835973573
# Iteration:     11,   Func. Count:     93,   Neg. LLF: 2389.019929540929
# Iteration:     12,   Func. Count:    100,   Neg. LLF: 2389.019789369354
# Iteration:     13,   Func. Count:    106,   Neg. LLF: 2389.019789369339
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2389.019789369354
#             Iterations: 13
#             Function evaluations: 106
#             Gradient evaluations: 13
# Iteration:      1,   Func. Count:      8,   Neg. LLF: 6653.7439182265225
# Iteration:      2,   Func. Count:     19,   Neg. LLF: 50638.527943137415
# Iteration:      3,   Func. Count:     29,   Neg. LLF: 38908.839320863124
# Iteration:      4,   Func. Count:     38,   Neg. LLF: 2814.143486270491
# Iteration:      5,   Func. Count:     47,   Neg. LLF: 2401.3299854770817
# Iteration:      6,   Func. Count:     55,   Neg. LLF: 3516.2440396503926
# Iteration:      7,   Func. Count:     63,   Neg. LLF: 2390.784271264674
# Iteration:      8,   Func. Count:     70,   Neg. LLF: 2390.790859799598
# Iteration:      9,   Func. Count:     78,   Neg. LLF: 2390.7862561968177
# Iteration:     10,   Func. Count:     86,   Neg. LLF: 2390.754254715157
# Iteration:     11,   Func. Count:     93,   Neg. LLF: 2390.753606643834
# Iteration:     12,   Func. Count:    100,   Neg. LLF: 2390.7536018538767
# Iteration:     13,   Func. Count:    106,   Neg. LLF: 2390.7536018538954
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2390.7536018538767
#             Iterations: 13
#             Function evaluations: 106
#             Gradient evaluations: 13
# Iteration:      1,   Func. Count:      8,   Neg. LLF: 6663.253433200694
# Iteration:      2,   Func. Count:     19,   Neg. LLF: 50447.98504822649
# Iteration:      3,   Func. Count:     29,   Neg. LLF: 39093.19438549885
# Iteration:      4,   Func. Count:     38,   Neg. LLF: 2807.4149195337836
# Iteration:      5,   Func. Count:     47,   Neg. LLF: 2456.0046241895293
# Iteration:      6,   Func. Count:     56,   Neg. LLF: 3513.5831452249417
# Iteration:      7,   Func. Count:     64,   Neg. LLF: 2392.8905736230618
# Iteration:      8,   Func. Count:     71,   Neg. LLF: 2392.8286502129704
# Iteration:      9,   Func. Count:     78,   Neg. LLF: 2392.8287610750676
# Iteration:     10,   Func. Count:     86,   Neg. LLF: 2392.822200173105
# Iteration:     11,   Func. Count:     93,   Neg. LLF: 2392.8218905087997
# Iteration:     12,   Func. Count:    100,   Neg. LLF: 2392.8217849280472
# Iteration:     13,   Func. Count:    106,   Neg. LLF: 2392.8217849280427
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2392.8217849280472
#             Iterations: 13
#             Function evaluations: 106
#             Gradient evaluations: 13
# Iteration:      1,   Func. Count:      8,   Neg. LLF: 6666.974158158049
# Iteration:      2,   Func. Count:     19,   Neg. LLF: 50451.71832340812
# Iteration:      3,   Func. Count:     29,   Neg. LLF: 70527.40035794154
# Iteration:      4,   Func. Count:     38,   Neg. LLF: 2827.465219147841
# Iteration:      5,   Func. Count:     47,   Neg. LLF: 19557.255699283563
# Iteration:      6,   Func. Count:     57,   Neg. LLF: 2405.6956912084465
# Iteration:      7,   Func. Count:     65,   Neg. LLF: 2394.4627633253067
# Iteration:      8,   Func. Count:     72,   Neg. LLF: 2394.347016257745
# Iteration:      9,   Func. Count:     79,   Neg. LLF: 2394.339350777619
# Iteration:     10,   Func. Count:     86,   Neg. LLF: 2394.3300622253532
# Iteration:     11,   Func. Count:     93,   Neg. LLF: 2394.3297771773723
# Iteration:     12,   Func. Count:    100,   Neg. LLF: 2394.3296973866663
# Iteration:     13,   Func. Count:    107,   Neg. LLF: 2394.3296779389766
# Iteration:     14,   Func. Count:    113,   Neg. LLF: 2394.3296779389875
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2394.3296779389766
#             Iterations: 14
#             Function evaluations: 113
#             Gradient evaluations: 14
# Iteration:      1,   Func. Count:      8,   Neg. LLF: 6670.970651150696
# Iteration:      2,   Func. Count:     19,   Neg. LLF: 50193.04617312898
# Iteration:      3,   Func. Count:     29,   Neg. LLF: 76411.62178152982
# Iteration:      4,   Func. Count:     38,   Neg. LLF: 2861.845443954102
# Iteration:      5,   Func. Count:     47,   Neg. LLF: 50895.33420637356
# Iteration:      6,   Func. Count:     57,   Neg. LLF: 2406.1944213329098
# Iteration:      7,   Func. Count:     65,   Neg. LLF: 2395.925827606088
# Iteration:      8,   Func. Count:     72,   Neg. LLF: 2395.8119926122745
# Iteration:      9,   Func. Count:     79,   Neg. LLF: 2395.805624399443
# Iteration:     10,   Func. Count:     86,   Neg. LLF: 2395.7976143973
# Iteration:     11,   Func. Count:     93,   Neg. LLF: 2395.7973050819023
# Iteration:     12,   Func. Count:    100,   Neg. LLF: 2395.797215195891
# Iteration:     13,   Func. Count:    107,   Neg. LLF: 2395.7971942509635
# Iteration:     14,   Func. Count:    113,   Neg. LLF: 2395.7971942509776
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2395.7971942509635
#             Iterations: 14
#             Function evaluations: 113
#             Gradient evaluations: 14
# Iteration:      1,   Func. Count:      8,   Neg. LLF: 6676.1208432752655
# Iteration:      2,   Func. Count:     19,   Neg. LLF: 50332.12089033061
# Iteration:      3,   Func. Count:     29,   Neg. LLF: 39212.645679558176
# Iteration:      4,   Func. Count:     38,   Neg. LLF: 2853.01261211387
# Iteration:      5,   Func. Count:     47,   Neg. LLF: 19617.78858848895
# Iteration:      6,   Func. Count:     57,   Neg. LLF: 2407.9488359855613
# Iteration:      7,   Func. Count:     65,   Neg. LLF: 2397.82934195134
# Iteration:      8,   Func. Count:     72,   Neg. LLF: 2397.7212099564886
# Iteration:      9,   Func. Count:     79,   Neg. LLF: 2397.712923122597
# Iteration:     10,   Func. Count:     86,   Neg. LLF: 2397.705974292602
# Iteration:     11,   Func. Count:     93,   Neg. LLF: 2397.705694783579
# Iteration:     12,   Func. Count:    100,   Neg. LLF: 2397.705606008439
# Iteration:     13,   Func. Count:    107,   Neg. LLF: 2397.705588550999
# Iteration:     14,   Func. Count:    113,   Neg. LLF: 2397.7055885510104
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2397.705588550999
#             Iterations: 14
#             Function evaluations: 113
#             Gradient evaluations: 14

# %%
######################################################## FORECASTS PLOT & RMSE ######################################################################

plt.plot(x_axis, recursive_forecast, label = 'Forecast returns recursive')
plt.plot(x_axis, real_value, label = 'Real returns')
plt.legend()
plt.title('Forecast with a recursive window with a GARCH(1, 1) model')
plt.show()

#RMSE
RMSE = np.sum(np.power(recursive_forecast-real_value,2))
print(f"The root mean squared errors are of {RMSE}")
print("_________________________________________________________________________________________________")



print("\nWe can notice that even if we're using the ARMA and the GARCH models, it is very difficult to have good forecasts for the financial data.")
print("This is why it is very difficult to model financial data with ATS models.")
print("_________________________________________________________________________________________________")
# Out:
# The root mean squared errors are of 487.20224986979343
# _________________________________________________________________________________________________
#
# We can notice that even if we're using the ARMA and the GARCH models, it is very difficult to have good forecasts for the financial data.
# This is why it is very difficult to model financial data with ATS models.
# _________________________________________________________________________________________________

# %%
################################################## VAR COMPUTATION ###############################################################
##################################################### IN-SAMPLE ##################################################################

df_const_returns = df[df['date'] <= datetime.datetime.strptime("2022-08-31", '%Y-%m-%d')]
df_const_returns = df_const_returns[df_const_returns['date'] > datetime.datetime.strptime("2018-01-02", '%Y-%m-%d')]


#First, we need the mean and volatility of the returns
mean = df_const_returns['returns'].mean()
vol = df_const_returns['returns'].std()
print("mean     :",mean)
print("vol      :",vol)

# Select our confidence interval
conf_level1 = 0.05

# Use SciPy ppf method to generate values for the inverse cumulative distribution function to a normal distribution
from scipy.stats import norm
cutoff1 = norm.ppf(conf_level1, mean, vol)
print("cutoff   :",cutoff1)
count = 0
for i in range(len(df_const_returns)):
    if df_const_returns['returns'].iloc[i] < cutoff1:
        count +=1
print(count)
print(f"{round(100 * count / len(df_const_returns), 2)} % of the returns are below the cutoff value : {cutoff1}%")
print("_______________________________________________________________________")
#Not exactly 5% because they are not normally distributed like all financial returns
# Out:
# mean     : -0.11444843155312782
# vol      : 2.0818882856583185
# cutoff   : -3.538849929125997
# 41
# 3.49 % of the returns are below the cutoff value : -3.538849929125997%
# _______________________________________________________________________

# %%
################################################## VAR COMPUTATION ###############################################################
################################## OUT OF SAMPLE, WITH DIFFERENT FORECAST METHODS ################################################

#Start with fixed window
print("Fixed Window")
#First, we need the mean and volatility of the returns
fixed_forecast = pd.Series(fixed_forecast)
mean = fixed_forecast.mean()
vol = fixed_forecast.std()
print("mean     :",mean)
print("vol      :",vol)

# Select our confidence interval
conf_level1 = 0.05

# Use SciPy ppf method to generate values for the inverse cumulative distribution function to a normal distribution
from scipy.stats import norm
cutoff1 = norm.ppf(conf_level1, mean, vol)
print("cutoff   :",cutoff1)
count = 0
for i in range(len(fixed_forecast)):
    if fixed_forecast[i] < cutoff1:
        count +=1
print(f"{round(100 * count / len(df_const_returns), 2)} % of the returns are below the cutoff value :{cutoff1}%")
print("_______________________________________________________________")

################################################################################################################################
#Then with expanding window
print("Expanding Window")
#First, we need the mean and volatility of the returns
expanding_forecast = pd.Series(expanding_forecast)
mean = expanding_forecast.mean()
vol = expanding_forecast.std()
print("mean     :",mean)
print("vol      :",vol)

# Select our confidence interval
conf_level1 = 0.05

# Use SciPy ppf method to generate values for the inverse cumulative distribution function to a normal distribution
from scipy.stats import norm
cutoff1 = norm.ppf(conf_level1, mean, vol)
print("cutoff   :",cutoff1)
count = 0
for i in range(len(expanding_forecast)):
    if expanding_forecast[i] < cutoff1:
        count +=1
print(count)
print(f"{round(100 * count / len(df_const_returns), 2)} % of the returns are below the cutoff value :{cutoff1}%")
print("_______________________________________________________________")



################################################################################################################################
#Finally with recursive window
print("Recursive Window")
#First, we need the mean and volatility of the returns
recursive_forecast = pd.Series(recursive_forecast)
mean = recursive_forecast.mean()
vol = recursive_forecast.std()
print("mean     :",mean)
print("vol      :",vol)

# Select our confidence interval
conf_level1 = 0.05

# Use SciPy ppf method to generate values for the inverse cumulative distribution function to a normal distribution
from scipy.stats import norm
cutoff1 = norm.ppf(conf_level1, mean, vol)
print("cutoff   :",cutoff1)
count = 0
for i in range(len(recursive_forecast)):
    if recursive_forecast[i] < cutoff1:
        count +=1
print(count)
print(f"{round(100 * count / len(df_const_returns), 2)} % of the returns are below the cutoff value :{cutoff1}%")
print("_______________________________________________________________")
# Out:
# Fixed Window
# mean     : -1.2303518480964954
# vol      : 5.190892986124095
# cutoff   : -9.768611003439675
# 0.0 % of the returns are below the cutoff value :-9.768611003439675%
# _______________________________________________________________
# Expanding Window
# mean     : 0.6216316949169367
# vol      : 3.80641788328771
# cutoff   : -5.639368566101801
# 1
# 0.09 % of the returns are below the cutoff value :-5.639368566101801%
# _______________________________________________________________
# Recursive Window
# mean     : 0.2789962952995747
# vol      : 4.670604286029951
# cutoff   : -7.403464104631885
# 1
# 0.09 % of the returns are below the cutoff value :-7.403464104631885%
# _______________________________________________________________
